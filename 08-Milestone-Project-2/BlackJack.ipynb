# %% [markdown]
# ####################################################
# ########## MILESTONE PROJECT 2 ####################
# ########## BLACK JACK  ##########################
# ###################################################

# %%
# setup cards
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}
# playing is true until said otherwise
playing = True

# setup each card
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
    
    def __str__(self):
        return (f'{self.rank} of {self.suit}')

# setup the deck. shuffle it. deal 2 cards to each player
class Deck:
    import random
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                card = [suit,rank]
                self.deck.append(card)
    def __str__(self):
        return str(self.deck)
        pass

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self,player,dealer):
        player.add_card(self.deck.pop())
        player.add_card(self.deck.pop())
        dealer.add_card(self.deck.pop())        
        dealer.add_card(self.deck.pop())
        return player,dealer
    
    
# setup each players hand
class Hand:
    def __init__(self):
        self.cards = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
    
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card[1]]
        
    def adjust_for_ace(self):
        if self.value > 21:
            self.value -= 10
            
            
# manage players chips
class Chips:
    
    def __init__(self):
        self.total = 100  # This can be set to a default value or supplied by a user input
        self.bet = 0
        
    def win_bet(self):
        self.total += self.bet
    
    def lose_bet(self):
        self.total -= self.bet


# hand hits
def hit(deck,hand):
    hand.add_card(deck.deck.pop())
    
    pass


# asks player if hit or stand
def hit_or_stand(deck,hand):
    global playing  # to control an upcoming while loop
    while True:
        stance = input("Enter H to hit or S to stand").upper()
        if stance == 'H' or stance == 'S':
            break
        
    if stance == 'H':
        hit(deck,hand)
    elif stance == 'S':
        playing = False
        print(f'Player stands at {player.value} \n')
    pass


# shows both player and one of dealers cards
def show_some(player,dealer):
    print("\nPlayers hand: ")
    print (f'{player.cards}  {player.value}')
    print("\nDealers hand: ")
    print (f'{dealer.cards[0]} & Hidden Card')
    pass
# shows all cards for both players
def show_all(player,dealer):
    print('\nPlayers hand: ')
    print(player.cards,'   ', player.value)
    print('\nDealers hand:')
    print(dealer.cards,'   ', dealer.value)
    pass



def player_busts():
    print('Player Busts')

def player_wins():
    print('Player Wins')

def dealer_busts():
    print('Dealer Busts')
    
def dealer_wins():
    print('Dealer Wins')
    
def push():
    print('Push, no winner')
    
    
    
# game loop
while True:
    # Print an opening statement
    print('WELCOME TO BLACK JACK \n')
    
    ace_adjusted = False
    # Create & shuffle the deck
    deck = Deck()
    Deck.shuffle(deck)
    
    
    # Set up the Player's chips
    player_chips = Chips()
    print(f'Player has {player_chips.total} chips \n')
    
   

    
    while True:  # recall this variable from our hit_or_stand function
     # Deal cards & Show cards (but keep one dealer card hidden)

        player = Hand()
        dealer = Hand()

        player, dealer = deck.deal(player, dealer)

        # Prompt the Player for their bet
        while True:
            try:
                player_chips.bet = int(input('Place your bet'))
                if player_chips.bet > player_chips.total:
                    print("You don't have that many chips")
                else:
                    break
            except:
                print('Please enter a valid bet')
        print(f'Your bet is {player_chips.bet} chips \n')
        
        show_some(player,dealer)
        
        while playing:
            # Prompt for Player to Hit or Stand
            hit_or_stand(deck,player)
            
            if player.value > 21 and not ace_adjusted:
                            for card in player.cards:
                                for rank in card:
                                    if rank == 'Ace':
                                        player.adjust_for_ace()
                                        ace_adjusted = True
                            if player.value > 21:      
                                player_busts()
                                playing = False
            elif player.value > 21 and ace_adjusted:
                playing = False
                                        
            # Show cards (but keep one dealer card hidden)
            show_some(player, dealer)

            # If player's hand exceeds 21, run player_busts() and break out of loop

            
            
            
            
        

        # If Player hasn't busted, play Dealer's hand until Dealer reaches 17
        if player.value < 22:
            while dealer.value < 17:
                hit(deck,dealer)
                print(dealer.cards, dealer.value)
                if dealer.value > 21:
                            for card in dealer.cards:
                                for rank in card:
                                    if rank == 'Ace':
                                        dealer.adjust_for_ace()
            # Show all cards
            print('\n')
            show_all(player, dealer)
            print('\n')
            # Run different winning scenarios
            if dealer.value > 21:
                dealer_busts()
                player_chips.win_bet()
            elif player.value == dealer.value:
                push()
            elif player.value > dealer.value:
                player_wins()
                player_chips.win_bet()
            else:
                dealer_wins()
                player_chips.lose_bet()
        else:
            player_busts()
            player_chips.lose_bet()

        # Inform Player of their chips total 
        print(f'Your new chip total is {player_chips.total}')
        # Ask to play again
        while True:
            if player_chips.total == 0:
                print("You're out of chips!")
                break
            answer = input('Would you like to play again? y or n')
            if answer.lower() == 'n':
                playing = False
                break
            elif answer.lower() == 'y':
                playing = True
                break
            else:
                print('Please enter a y or n \n')
        if playing == False:
            break
    break
# Out:
# WELCOME TO BLACK JACK
#
# Player has 100 chips
# Place your bet 100
# Your bet is 100 chips
#
#
# Players hand:
# [['Diamonds', 'Four'], ['Hearts', 'Jack']]  14
#
# Dealers hand:
# ['Diamonds', 'Five'] & Hidden Card
# Enter H to hit or S to stand s
# Player stands at 14
#
#
# Players hand:
# [['Diamonds', 'Four'], ['Hearts', 'Jack']]  14
#
# Dealers hand:
# ['Diamonds', 'Five'] & Hidden Card
# [['Diamonds', 'Five'], ['Diamonds', 'Six'], ['Diamonds', 'Nine']] 20
#
#
#
# Players hand:
# [['Diamonds', 'Four'], ['Hearts', 'Jack']]     14
#
# Dealers hand:
# [['Diamonds', 'Five'], ['Diamonds', 'Six'], ['Diamonds', 'Nine']]     20
#
#
# Dealer Wins
# Your new chip total is 0
# You're out of chips!
